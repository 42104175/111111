# %% [markdown]
# # 金融科技第一次实验 Fintech WorkShop No.1
# ## 实验目标：熟悉Git、GitHub、Markdown和Jupyter Notebook
# ## 实验内容
# - git [官方网站](https://git-scm.com/doc)
# - GitHub [官方网站](https://www.github.com)
# - Markdown [CheatSheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
# - Jupyter Notebook [CheatSheet](https://res.cloudinary.com/dyd911kmh/image/upload/v1676302533/Marketing/Blog/Jupyterlab_Cheat_Sheet.pdf)

# %% [markdown]
# ### 1. GIT和Github
# 因为我们一直在不断进步，所以我们也不断修改我们的文档和代码。：）
# GIT能够帮助我们更好地进行版本管理。“版本控制”，也称为版本控制，源代码控制或软件配置管理（SCM），是**存储和管理文档、代码的更改信息。**
#
# 跟踪并重现工作的每一步在软件世界中：它被称为版本控制！
#
# （优秀的）版本控制工具给你带来了什么？
#
# 安心（备份） 自由（探索性分支） 协作（同步）
#
# ####  GIT常用命令和用法
#
# - **安装git** 参见官网安装文档 [link](https://git-scm.com/book/zh/v2/%E8%B5%B7%E6%AD%A5-%E5%AE%89%E8%A3%85-Git)
#
#
# - **在本地创建存储库repo**    （<font color=red>*请补齐操作步骤*</font>）
#   1. 设置git全局用户名
#
#  `$ git config --global user.name "42104175"
#  $ git config --global user.email "475485092@qq.com" `
#
#   2. 初始化当前文件夹为git仓库
#
#  `$ git init`
#   3. 设置git当前仓库用户名
#
#  `$ git config user.name "42104175"
#  $ git config user.email "475485092@qq.com" `
#
#   4. 检查当前用户名设置
#
#  `$ git config --list`
#
#
# - **在本地创建文件、添加文件和修改文件时的git操作**
#   （<font color=red>*请补齐操作步骤*</font>）
#   1. 创建本文档workshop.ipynb
#
#  `$ touch workshop.ipynb`
#   2. 添加和确认提交此文件
#
#  `$ git add workshop.ipynb
#  $ git commit -m "first commit"`
#   3. 修改文件后再次确认提交
#
#  `$vim workshop.ipynb
#  $ git add workshop.ipynb
#   $ git commit -m "second commit"`
#   4. 查看当前仓库状态
#
#  `$ git status`
#
#
# - **创建远程仓库[ref](https://docs.github.com/zh/get-started/importing-your-projects-to-github/importing-source-code-to-github/adding-locally-hosted-code-to-github)**
#    （<font color=red>*请补齐操作步骤*</font>）
#   1. 在github上创建账号并获取ssh-key
#
#   ### **第一步，在gitbash中编写如下代码，获取公共密钥并复制**
#
#
#   ### **第二步，将复制的公钥粘贴到GitHub中，即可获得ssh-key**
#
#
#
#   2. 在github上创建一个没有readme、许可协议和git ignore文件的新存储库
#   ### **在图示箭头区域可创建一个new repository**
#
#
#
#   3. 在上一步创建的本地仓库中添加远程仓库地址（github）
#
#  `$ cd mynewproject
#  $ git remote add mynewproject https://github.com/42104175/111111
#
#   4. 将本地仓库的更改推送到github中
#
#  `$ git checkout master
#  $ git push mynewproject master`
#
#
# - **获取他人（组长）的远程仓库到本地并完成更改后提交** （<font color=red>*请补齐操作步骤*</font>）
#
# - **组长合并他人的提交** （<font color=red>*请补齐操作步骤*</font

# %%
### 2.  Markdown常用命令和用法
#### 常用语法 

- 标题 （这是xxx的自我介绍标题）  
创建标题要在标题内容前面添加“#”，“#”的数量代表了标题的级别      

- 粗体、斜体和~~删除线~~  （我的**兴趣爱好**， 我的*擅长*， 我改进了~~哪些我不喜欢的内容~~）  
粗体：在需要加粗的文本前后添加两个星号（*）或下划线（_）可以对文本加粗。  
斜体：在需要倾斜的文本前后添加一个星号（*）或下划线（_）可以倾斜文本。  
删除线：在需要删除的文本前后添加两个波浪号（~）。    

- 有序列表和无序列表  
有序列表：  
  1.First item  
  2.Second item  
  3.Third item  
  4.Fourth item  
无序列表：  
  + First item  
  + Second item
  + Third item
  + Fourth item  
要创建无序列表，请在每个列表前添加破折号（-）、星号（*）或加号（+）。  

- [超链接](https://www.swufe.edu.cn)  
Method 1:  
    超链接Markdown语法代码：[超链接显示名]（超链接地址"超链接title"）  
Method 2:  
    使用尖括号可以很方便地把URL或者email地址变成可点击的链接

- 插入图像  
要添加图像，请使用感叹号（！），然后在方括号增加替代文本，图片链接放在圆括号里，括号里的链接后可以增加一个可选的图片标题文本。  
插入图片Markdown语法代码：！[这是图片]（图片链接"图片title"）  

- 插入`代码`以突出显示
- 插入整块引用
  > 这是我最近最喜欢的一句话，是由某某某所讲
- 插入视频  
<video scr="视频链接"></video><iframe height=40 width=51 scr="视频链接">


请补充组员的基本信息

|姓名|学号|专业及年级|小组代号|
|---|---|---|---|
|邓佳欣|42104175|2021CFA|111|
|郭文斐|42112105|2021CFA|111|
|李兰亭|42108127|2021CFA|111|
|潘靓|42112088|2021CFA|111|
|史馨茹|42127013|2021CFA|111|
|肖扬|42133028|2021CFA|111|

# %%
这是李兰亭的自我介绍标题
我的**兴趣爱好是**和猫猫狗狗玩，我*擅长和猫猫狗狗相处*，我改进了~~拖延的习惯~~
"Be you, be unique, be crazy, you'er beautiful."
>这是我最近最喜欢的一句话，是由TEN讲的

# %%
#### Latex####

- 二次项定理

$$ (x+y)^n = \sum_{k=0}^n {n \choose k} x^{n - k} y^k. $$


- 指数函数

$$ e^x = \lim_{n \to \infty} \left( 1+ \frac{x}{n} \right)^n. $$

- 柯西不等式

$$
  \left( \sum_{k=1}^n a_k b_k \right)^2 \leq
  \left( \sum_{k=1}^n a_k^2 \right)
  \left( \sum_{k=1}^n b_k^2 \right).
$$

- 贝叶斯定理

$$ P(A \mid B) = \frac{P(B \mid A) \, P(A)}{P(B)}. $$


- 欧拉公式

**Theorem** (Euler's summation formula). _If $ f $has a continuous derivative $ f' $ on the interval $ [y, x], $ where $ 0 < y < x,
$ then_
\begin{align}
  \sum_{y < n \le x} f(n)
    = & \int_y^x f(t) \, dt + \int_y^x (t - [t]) f'(t) \, dt
       \notag \\
       & + f(x)([x] - x) - f(y)([y] - y). \label{theorem}
\end{align}

_Proof.
_ Let $ m = [y] $ and $ k = [x]. $ For integers $ n $ and $ n - 1 $ in $ [y, x] $ we have 
\begin{align*}
  \int_{n - 1}^n [t] f'(t) \, dt
    & = \int_{n - 1}^n (n - 1) f'(t) \, dt \\
    & = (n - 1) \{ f(n) - f(n - 1) \} \\
    & = \{n f(n) - (n - 1) f(n - 1)\} - f(n).
\end{align*}
Summing from $ n = m + 2 $ to $ n = k $ we find
that the first sum telescopes, hence
\begin{align*}
  \int_{m + 1}^k [t] f'(t) \, dt
    & = k f(k) - (m + 1) f(m + 1) - \sum_{n = m + 2}^k f(n) \\
    & = k f(k) - m f(m + 1) - \sum_{y < n \le x} f(n).
\end{align*}
Therefore
\begin{align}
  \sum_{y < n \le x} f(n)
    & = - \int_{m + 1}^k [t] f'(t) \, dt + k f(k) - m f(m + 1) \notag \\
    & = - \int_y^x [t] f'(t) \, dt + k f(x) - m f(y). \label{summation}
\end{align}
Integration by parts gives us
$$
\int_y^x f(t) \, dt = x f(x) - y f(y) - \int_y^x t f'(t) \, dt,
$$

# %%
### 3.Jupyter的基本用法
# !python -V
git clone https://github.com/swufe-courses/workshop1--markdown-git-jupyter-111
   29  git add .
   30  cd workshop1--markdown-git-jupyter-111/
   31  git add
   32  git add .
   33  git commit -m "first"
   34  git push -u origin main
